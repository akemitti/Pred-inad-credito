# %% [markdown]
# <a href="https://colab.research.google.com/github/akemitti/Pred-inad-credito/blob/main/notebook04_mistral_estatisticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Aviso:
# O notebook foi criado utilizando a GPU, é necessário conectar com a mesma para rodar os códigos.

# %% [markdown]
# ## Mistral
#
#
# > **Pré-requisito**: ter o Ollama instalado e o modelo `mistral` baixado.
# > Execute no terminal: `ollama pull mistral` e `ollama serve`.
#
# Se não disponível, a célula gera scores `NaN` e o modelo é excluído do comparativo.

# %% [markdown]
# ## Instalação das dependências

# %%
# !pip install ollama
# Out:
# Collecting ollama
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.12/dist-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.12/dist-packages (from ollama) (2.12.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (0.4.2)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.6.1

# %%
# !pip install colab-xterm
# %load_ext colabxterm
# Out:
# Collecting colab-xterm
#   Downloading colab_xterm-0.2.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: ptyprocess~=0.7.0 in /usr/local/lib/python3.12/dist-packages (from colab-xterm) (0.7.0)
# Requirement already satisfied: tornado>5.1 in /usr/local/lib/python3.12/dist-packages (from colab-xterm) (6.5.1)
# Downloading colab_xterm-0.2.0-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: colab-xterm
# Successfully installed colab-xterm-0.2.0

# %%
# !apt-get update
# !apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# !which ollama
# !nohup ollama serve >/tmp/ollama.log 2>&1 &
# !sleep 5
# !ollama pull mistral
# !ollama run mistral "Qual é a capital do Brasil?"
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [89.0 kB]
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.1 MB]
# Get:13 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.8 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,191 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,292 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,983 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,601 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,066 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,863 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.7 kB]
# Get:23 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [61.6 kB]
# Get:24 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,862 kB]
# Fetched 38.7 MB in 8s (4,698 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 54 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 1s (616 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# /usr/local/bin/ollama
#
#  A capital do Brasil é Brasília. A cidade foi fundada em 1960 e se localiza
# localiza no centro-oeste do país, no Distrito Federal. Anteriormente, o Rio
# Rio de Janeiro era a capital federal brasileira, mas devido à necessidade d
# de melhor organização administrativa e de distância entre as instituições g
# governamentais e as atividades da capital econômica, a cidade do Rio de Jan
# Janeiro foi transferida para Brasília.

# %% [markdown]
# ## Leitura da base de dados
#
# Em vez de extrair texto dos PDFs, carregamos diretamente o CSV com os textos já extraídos e os scores dos demais modelos. A coluna `texto` equivale ao `Clean_Text` do notebook original.

# %%
import os
import re
import json
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from tqdm import tqdm
import ollama
warnings.filterwarnings('ignore')

# ── Fonte de dados: CSV com textos e scores já calculados ────────────────────
URL_BASE = "https://raw.githubusercontent.com/akemitti/Pred-inad-credito/main/base_sentimentos_estatisticas_sem_mistral.csv"

try:
    df_base = pd.read_csv("base_sentimentos_estatisticas_sem_mistral.csv")
    print("Base carregada do disco local.")
except FileNotFoundError:
    df_base = pd.read_csv(URL_BASE)
    print("Base carregada do GitHub.")

# Normalizar colunas
df_base.columns = [c.strip().lower() for c in df_base.columns]
if 'unnamed: 0' in df_base.columns:
    df_base = df_base.drop(columns=['unnamed: 0'])

df_base["data"] = pd.to_datetime(df_base["data"], errors="coerce")
df_base["tipo"] = df_base["tipo"].str.lower().str.strip()
df_base = df_base.sort_values("data").reset_index(drop=True)

# ── Filtro: somente documentos a partir de 2022-12 ──────────────────────────
df_base = df_base[df_base["data"] >= "2022-12-01"].reset_index(drop=True)

print(f"Documentos carregados : {len(df_base)}")
print(f"Período               : {df_base['data'].min().date()} a {df_base['data'].max().date()}")
print(f"Colunas               : {list(df_base.columns)}")
df_base[["data", "arquivo", "tipo",
         "score_nltk", "score_textblob", "score_bert", "score_finbert"]].head()
# Out:
# Base carregada do GitHub.
# Documentos carregados : 37
# Período               : 2022-12-01 a 2025-12-01
# Colunas               : ['data', 'texto', 'arquivo', 'tipo', 'score_nltk', 'score_textblob', 'score_bert', 'score_finbert']
#         data                                            arquivo          tipo  \
# 0 2022-12-01  202212_Texto_de_estatisticas_monetarias_e_de_c...  estatisticas
# 1 2023-01-01  202301_Texto_de_estatisticas_monetarias_e_de_c...  estatisticas
# 2 2023-02-01  202302_Texto_de_estatisticas_monetarias_e_de_c...  estatisticas
# 3 2023-03-01  202303_Texto_de_estatisticas_monetarias_e_de_c...  estatisticas
# 4 2023-04-01  202304_Texto_de_estatisticas_monetarias_e_de_c...  estatisticas
#
#    score_nltk  score_textblob  score_bert  score_finbert
# 0     -0.9920        0.000000   -1.000000       0.237051
# 1     -0.9923        0.233333   -1.000000      -0.076548
# 2     -0.9843       -0.266667   -0.714286      -0.085113
# 3     -0.9884       -0.200000   -1.000000       0.019449
# 4     -0.9843        0.000000   -0.800000       0.303486

# %% [markdown]
# ## LLM Mistral
#
# Utilizamos a LLM Mistral para a análise de sentimento. A escolha se dá pelo seu bom desempenho, compatibilidade com o Google Colab, suporte ao português e por ser um modelo de código aberto que permite reprodutibilidade.
#
# Sites de referência:
# - https://www.autonomous.ai/ourblog/llama-vs-mistral-which-performs-better
# - https://medium.com/@abonia/running-ollama-in-google-colab-free-tier-545609258453
# - https://www.ibm.com/think/topics/mistral-ai

# %% [markdown]
# ### Funções de análise
#
#  `analisar_documentos` recebe um DataFrame em vez de um dicionário de PDFs — o campo `texto` já contém o texto completo extraído.

# %%
def analisar_sentimento(texto_documento):
    SYSTEM_PROMPT = """
    Você é um economista de política monetária no Brasil. Sua tarefa é analisar o sentimento de um documento do Banco Central do Brasil.
    Forneça um score de sentimento de -1.0 (muito negativo/hawkish) a 1.0 (muito positivo/dovish).

    Responda APENAS com um objeto JSON contendo UMA ÚNICA CHAVE, "score".

    Exemplo de resposta:
    {"score": -0.45}
    """

    try:
        response = ollama.chat(
            model='mistral',
            messages=[
                {'role': 'system', 'content': SYSTEM_PROMPT},
                {'role': 'user',   'content': texto_documento}
            ],
            options={'temperature': 0.2},
            format='json'
        )

        response_text = response['message']['content']
        print(f"Resposta bruta do LLM: {response_text}")

        data = json.loads(response_text)

        if 'score' in data and isinstance(data['score'], (int, float)):
            score = float(data['score'])
            score = max(-1.0, min(1.0, score))
            return score
        else:
            print("Erro: Chave 'score' não encontrada ou não é um número no JSON.")
            return 0.0

    except json.JSONDecodeError:
        print(f"Erro: O LLM não retornou um JSON válido. Resposta: '{response_text}'")
        return 0.0
    except Exception as e:
        print(f"Erro inesperado ao chamar o Ollama: {e}")
        return 0.0

# %%
def analisar_documentos_csv(df, coluna_texto="texto", paginas_para_analisar=2):
    """
    Equivalente à função analisar_documentos() do notebook original.
    Recebe um DataFrame com coluna de texto já extraído (sem necessidade de PDFs).

    O parâmetro paginas_para_analisar mantém a compatibilidade lógica:
    como o texto já está concatenado, usamos os últimos N*1500 caracteres
    como aproximação das últimas N páginas (~750 palavras/página).
    """
    CHARS_POR_PAGINA = 1500
    limite_chars = paginas_para_analisar * CHARS_POR_PAGINA

    resultados_parciais = []
    print(f"\n--- Iniciando Análise de Sentimento: Relatório de Estatísticas ---")

    for _, row in df.iterrows():
        nome_arquivo = str(row.get("arquivo", ""))
        data         = row.get("data", None)
        texto_bruto  = str(row.get(coluna_texto, ""))

        if not texto_bruto.strip():
            resultados_parciais.append((nome_arquivo, "Relatório de Estatísticas", data, 0.0, "DOCUMENTO_VAZIO", ""))
            continue

        # Replicar o tratamento original: join + limpeza de espaços + últimas N páginas
        texto_para_analise = ' '.join(texto_bruto.split())   # equivale ao join de páginas + split
        texto_para_analise = texto_para_analise[-limite_chars:]  # últimas N páginas (aprox.)

        if len(texto_para_analise) < 50:
            resultados_parciais.append((nome_arquivo, "Relatório de Estatísticas", data, 0.0, "TEXTO_CURTO", texto_para_analise))
            continue

        score_sentimento = analisar_sentimento(texto_para_analise)
        print(f"Data: {data} | Score Mistral: {score_sentimento:.4f}")

        resultados_parciais.append((nome_arquivo, "Relatório de Estatísticas", data, score_sentimento, "SUCESSO", texto_para_analise))

    return resultados_parciais

# %% [markdown]
# ### Execução da análise

# %%
paginas = 2  # Usar as n últimas páginas (equivalente ao notebook original)

resultados_finais = analisar_documentos_csv(df_base, coluna_texto="texto", paginas_para_analisar=paginas)

print("\n--- Análise Total Concluída ---")

df_resultados = pd.DataFrame(
    resultados_finais,
    columns=["Arquivo", "Tipo", "Data", "Score_Mistral", "Status", "Clean_Text"]
)

df_analise = df_resultados[df_resultados['Status'] == 'SUCESSO'].copy()
df_analise = df_analise.dropna(subset=['Data'])
df_analise = df_analise.sort_values(by="Data")

print(f"Documentos analisados com sucesso: {len(df_analise)}/{len(df_resultados)}")
df_analise[['Data', 'Tipo', 'Score_Mistral', 'Clean_Text']].head()
# Out:
# --- Iniciando Análise de Sentimento: Relatório de Estatísticas ---
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2019-01-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2019-02-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2019-03-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.5}
# Data: 2019-04-01 00:00:00 | Score Mistral: -0.5000
# Resposta bruta do LLM: {"score": -0.5}
# Data: 2019-05-01 00:00:00 | Score Mistral: -0.5000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2019-06-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.1}
# Data: 2019-07-01 00:00:00 | Score Mistral: -0.1000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2019-08-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2019-09-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2019-10-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2019-11-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2019-12-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": 0.5}
# Data: 2020-01-01 00:00:00 | Score Mistral: 0.5000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2020-02-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": 0.2}
# Data: 2020-03-01 00:00:00 | Score Mistral: 0.2000
# Resposta bruta do LLM: {"score": 0.5}
# Data: 2020-04-01 00:00:00 | Score Mistral: 0.5000
# Resposta bruta do LLM: {"score": 0.5}
# Data: 2020-05-01 00:00:00 | Score Mistral: 0.5000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2020-06-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2020-07-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.5}
# Data: 2020-08-01 00:00:00 | Score Mistral: -0.5000
# Resposta bruta do LLM: {"score": 0.2}
# Data: 2020-09-01 00:00:00 | Score Mistral: 0.2000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2020-10-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2020-11-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": 0.6}
# Data: 2020-12-01 00:00:00 | Score Mistral: 0.6000
# Resposta bruta do LLM: {"score": 0.3}
# Data: 2021-01-01 00:00:00 | Score Mistral: 0.3000
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2021-02-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2021-03-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2021-04-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": 0.8}
# Data: 2021-05-01 00:00:00 | Score Mistral: 0.8000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2021-06-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2021-07-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2021-08-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2021-09-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2021-10-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": -0.7}
# Data: 2021-11-01 00:00:00 | Score Mistral: -0.7000
# Resposta bruta do LLM: {"score": 0.65}
# Data: 2021-12-01 00:00:00 | Score Mistral: 0.6500
# Resposta bruta do LLM: {"score": 0.5}
# Data: 2022-01-01 00:00:00 | Score Mistral: 0.5000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2022-02-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.7}
# Data: 2022-03-01 00:00:00 | Score Mistral: -0.7000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2022-05-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.25}
# Data: 2022-07-01 00:00:00 | Score Mistral: -0.2500
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2022-09-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": 0.65}
# Data: 2022-10-01 00:00:00 | Score Mistral: 0.6500
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2022-11-01 00:00:00 | Score Mistral: -0.3000

# %%
paginas = 2  # Usar as n últimas páginas (equivalente ao notebook original)

resultados_finais = analisar_documentos_csv(df_base, coluna_texto="texto", paginas_para_analisar=paginas)

print("\n--- Análise Total Concluída ---")

df_resultados = pd.DataFrame(
    resultados_finais,
    columns=["Arquivo", "Tipo", "Data", "Score_Mistral", "Status", "Clean_Text"]
)

df_analise = df_resultados[df_resultados['Status'] == 'SUCESSO'].copy()
df_analise = df_analise.dropna(subset=['Data'])
df_analise = df_analise.sort_values(by="Data")

print(f"Documentos analisados com sucesso: {len(df_analise)}/{len(df_resultados)}")
df_analise[['Data', 'Tipo', 'Score_Mistral', 'Clean_Text']].head()
# Out:
# --- Iniciando Análise de Sentimento: Relatório de Estatísticas ---
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2022-12-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2023-01-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": 0.7}
# Data: 2023-02-01 00:00:00 | Score Mistral: 0.7000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2023-03-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": 0.65}
# Data: 2023-04-01 00:00:00 | Score Mistral: 0.6500
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2023-05-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.5}
# Data: 2023-06-01 00:00:00 | Score Mistral: -0.5000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2023-07-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.5}
# Data: 2023-08-01 00:00:00 | Score Mistral: -0.5000
# Resposta bruta do LLM: {"score": -0.15}
# Data: 2023-09-01 00:00:00 | Score Mistral: -0.1500
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2023-10-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.5}
# Data: 2023-11-01 00:00:00 | Score Mistral: -0.5000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2023-12-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.65}
# Data: 2024-01-01 00:00:00 | Score Mistral: -0.6500
# Resposta bruta do LLM: {"score": 0.2}
# Data: 2024-02-01 00:00:00 | Score Mistral: 0.2000
# Resposta bruta do LLM: {"score": -0.1}
# Data: 2024-03-01 00:00:00 | Score Mistral: -0.1000
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2024-04-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2024-05-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2024-06-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.7}
# Data: 2024-07-01 00:00:00 | Score Mistral: -0.7000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2024-08-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2024-09-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2024-10-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.25}
# Data: 2024-11-01 00:00:00 | Score Mistral: -0.2500
# Resposta bruta do LLM: {"score": -0.15}
# Data: 2024-12-01 00:00:00 | Score Mistral: -0.1500
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2025-01-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.5}
# Data: 2025-02-01 00:00:00 | Score Mistral: -0.5000
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2025-03-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2025-04-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2025-05-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2025-06-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": -0.2}
# Data: 2025-07-01 00:00:00 | Score Mistral: -0.2000
# Resposta bruta do LLM: {"score": -0.1}
# Data: 2025-08-01 00:00:00 | Score Mistral: -0.1000
# Resposta bruta do LLM: {"score": -0.6}
# Data: 2025-09-01 00:00:00 | Score Mistral: -0.6000
# Resposta bruta do LLM: {"score": 0.65}
# Data: 2025-10-01 00:00:00 | Score Mistral: 0.6500
# Resposta bruta do LLM: {"score": -0.3}
# Data: 2025-11-01 00:00:00 | Score Mistral: -0.3000
# Resposta bruta do LLM: {"score": 0.5}
# Data: 2025-12-01 00:00:00 | Score Mistral: 0.5000
#
# --- Análise Total Concluída ---
# Documentos analisados com sucesso: 37/37
#         Data                       Tipo  Score_Mistral  \
# 0 2022-12-01  Relatório de Estatísticas          -0.60
# 1 2023-01-01  Relatório de Estatísticas          -0.30
# 2 2023-02-01  Relatório de Estatísticas           0.70
# 3 2023-03-01  Relatório de Estatísticas          -0.20
# 4 2023-04-01  Relatório de Estatísticas           0.65
#
#                                           Clean_Text
# 0  tingiu 28,2% a.a., com variações de 0,2 p.p. e...
# 1  ursos do Proagro, R$249 milhões; resgate de de...
# 2  ses: i) Crédito ampliado ao setor não financei...
# 3  No sen tido expansionista impactaram as operaç...
# 4   impactaram de forma expansionista as operaçõe...

# %% [markdown]
# ### Visualização — Score Mistral ao longo do tempo

# %%
cores = {"Relatório de Estatísticas": "#d11518"}

plt.figure(figsize=(15, 7))

sns.lineplot(
    data=df_analise,
    x="Data",
    y="Score_Mistral",
    hue="Tipo",
    marker="o",
    style="Tipo",
    palette=cores
)

plt.axhline(0, color='grey', linestyle='--', lw=1)
plt.title("Evolução do Sentimento das Relatórios de Estatísticas Monetárias e de Crédito (Análise via Mistral)")
plt.ylabel("Score de Sentimento (Hawkish < 0 | Dovish > 0)")
plt.xlabel("Data do Documento")
plt.legend(title="Tipo de Documento")
plt.grid(axis='y', linestyle=':', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df_export_mistral = (
    df_analise.rename(columns={
        "Arquivo": "arquivo",
        "Tipo": "tipo",
        "Data": "data",
        "Score_Mistral": "score",
        "Status": "status",
        "Clean_Text": "clean_text"
    })
    [["data", "arquivo", "tipo", "score", "status", "clean_text"]]
    .sort_values("data")
    .reset_index(drop=True)
)

df_export_mistral.to_csv("base_sentimento_estatisticas.csv", index=False)
print("base_sentimento_estatisticas.csv salvo.")
df_export_mistral.head()
# Out:
# base_sentimento_estatisticas.csv salvo.
#         data                                            arquivo  \
# 0 2022-12-01  202212_Texto_de_estatisticas_monetarias_e_de_c...
# 1 2023-01-01  202301_Texto_de_estatisticas_monetarias_e_de_c...
# 2 2023-02-01  202302_Texto_de_estatisticas_monetarias_e_de_c...
# 3 2023-03-01  202303_Texto_de_estatisticas_monetarias_e_de_c...
# 4 2023-04-01  202304_Texto_de_estatisticas_monetarias_e_de_c...
#
#                         tipo  score   status  \
# 0  Relatório de Estatísticas  -0.60  SUCESSO
# 1  Relatório de Estatísticas  -0.30  SUCESSO
# 2  Relatório de Estatísticas   0.70  SUCESSO
# 3  Relatório de Estatísticas  -0.20  SUCESSO
# 4  Relatório de Estatísticas   0.65  SUCESSO
#
#                                           clean_text
# 0  tingiu 28,2% a.a., com variações de 0,2 p.p. e...
# 1  ursos do Proagro, R$249 milhões; resgate de de...
# 2  ses: i) Crédito ampliado ao setor não financei...
# 3  No sen tido expansionista impactaram as operaç...
# 4   impactaram de forma expansionista as operaçõe...
